# %%
import pandas as pd

# %%
df= pd.read_csv('data.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df2_hist= df.groupby('city')['price'].value_counts().reset_index(name='count')
df2_hist
df2_histpivot = df2_hist.pivot_table(index='city', columns='price', values='count')
df2_histpivot
# Out:
# price                0.0         7800.0      80000.0     83000.0     \
# city
# Algona                      NaN         NaN         NaN         NaN
# Auburn                      1.0         NaN         NaN         NaN
# Beaux Arts Village          NaN         NaN         NaN         NaN
# Bellevue                    5.0         NaN         NaN         NaN
# Black Diamond               1.0         NaN         NaN         NaN
# Bothell                     NaN         NaN         NaN         NaN
# Burien                      2.0         NaN         NaN         NaN
# Carnation                   NaN         NaN         1.0         NaN
# Clyde Hill                  2.0         NaN         NaN         NaN
# Covington                   1.0         NaN         NaN         NaN
# Des Moines                  NaN         NaN         NaN         NaN
# Duvall                      NaN         NaN         NaN         NaN
# Enumclaw                    1.0         NaN         NaN         NaN
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df2_histpivot,cmap='viridis',annot=True)
plt.xlabel('city')
plt.ylabel('Price')
plt.suptitle('Average price vs City')
plt.show()

# %%
# @title Price vs Living Space, Colored by Floors

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['sqft_living'], df['price'], c=df['floors'], cmap='viridis', alpha=0.7)
plt.colorbar(label='Floors')
plt.xlabel('Sqft Living')
plt.ylabel('Price')
_ = plt.title('Price vs Living Space, Colored by Floors')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df['sqft_living'].unique()
# Out:
# array([ 1340,  3650,  1930,  2000,  1940,   880,  1350,  2710,  2430,
#         1520,  1710,  2920,  2330,  1090,  2910,  1200,  1570,  3110,
#         1370,  1180,  2240,  1450,  1750,  2730,  1600,  2090,  2360,
#         2200,  2820,  2600,  1560,  2860,  1820,  3630,  3240,   800,
#         1850,  1960,  2390,  1580,  1480,   850,  1770,  1210,  1160,
#         1970,  1270,  3310,  1800,  2210,  1920,  2190,  3660,  1320,
#         1630,  2680,  2540,   900,  1650,  1010,  2530,  2850,  2280,
#         1900,  1330,  2170,  2120,  2490,  1990,  3690,  2340,  2110,
#         1140,  1410,  3180,  2160,  2350,  2740,  1680,  3090,  4010,
#         2010,  2370,  1840,  2070,  4340,   840,  1240,  1390,  2310,
#         1050,  2550,  1120,  2230,   810,  3190,  1670, 13540,  1880,
#         1550,  2050,  2220,  2300,  1790,  2440,  3400,  4420,  1571,
#         1620,  1408,  3040,  4490,  1590,  2450,  1440,  1100,  2150,
# ...

# %%
X= df[['sqft_living']]
Y= df['price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error

# %%
scaler=StandardScaler()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
model= LinearRegression()

# %%
model.fit(X_train_scaled,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred= model.predict(X_test_scaled)

# %%
mse= mean_squared_error(Y_test,Y_pred)
r2= r2_score(Y_test,Y_pred)

# %%
mse
# Out:
# 990204087727.1417

# %%
r2
# Out:
# 0.029065410341410414

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.scatter(X_test,Y_test,color='Blue',label='Actual Price')
plt.scatter(X_test,Y_pred,color='Red',label='Predicted Price')
plt.plot(X_test,Y_pred,color='Green',label='Regression line')
plt.xlabel('Condition')
plt.ylabel('Price')
plt.suptitle(f'Regression of Actual vs Predicted Price with r2:{r2:.2f}')
plt.legend()
plt.show()
